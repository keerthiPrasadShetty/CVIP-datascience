# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')
from matplotlib import pyplot as pt
import seaborn as sns

# %%
data=pd.read_csv('diabetes_prediction_dataset.csv')
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
data.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
data.shape
# Out:
# (100000, 9)

# %%
data.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
data.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
data.iloc[0:99999,0:2]
# Out:
#        gender   age
# 0      Female  80.0
# 1      Female  54.0
# 2        Male  28.0
# 3      Female  36.0
# 4        Male  76.0
# ...       ...   ...
# 99994  Female  36.0
# 99995  Female  80.0
# 99996  Female   2.0
# 99997    Male  66.0
# 99998  Female  24.0
#
# [99999 rows x 2 columns]

# %%
data.mean()
# Out:
# age                     41.885856
# hypertension             0.074850
# heart_disease            0.039420
# bmi                     27.320767
# HbA1c_level              5.527507
# blood_glucose_level    138.058060
# diabetes                 0.085000
# dtype: float64

# %%
data.median()
# Out:
# age                     43.00
# hypertension             0.00
# heart_disease            0.00
# bmi                     27.32
# HbA1c_level              5.80
# blood_glucose_level    140.00
# diabetes                 0.00
# dtype: float64

# %%
data.min()
# Out:
# gender                  Female
# age                       0.08
# hypertension                 0
# heart_disease                0
# smoking_history        No Info
# bmi                      10.01
# HbA1c_level                3.5
# blood_glucose_level         80
# diabetes                     0
# dtype: object

# %%
data.max()
# Out:
# gender                       Other
# age                           80.0
# hypertension                     1
# heart_disease                    1
# smoking_history        not current
# bmi                          95.69
# HbA1c_level                    9.0
# blood_glucose_level            300
# diabetes                         1
# dtype: object

# %%
data['bmi'].value_counts()
# Out:
# 27.32    25495
# 23.00      103
# 27.12      101
# 24.96      100
# 27.80      100
#          ...
# 44.84        1
# 69.37        1
# 46.54        1
# 64.61        1
# 53.27        1
# Name: bmi, Length: 4247, dtype: int64

# %%
#Data analysis using BMI

# %%
sns.distplot(data['bmi'],bins=30)
pt.show()

# %%
sns.countplot(x='smoking_history',data=data)
# Out:
# <AxesSubplot:xlabel='smoking_history', ylabel='count'>

# %%
sns.countplot(x='gender',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='heart_disease',data=data)
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='count'>

# %%
sns.countplot(x='HbA1c_level',data=data)
# Out:
# <AxesSubplot:xlabel='HbA1c_level', ylabel='count'>

# %%
sns.countplot(x='blood_glucose_level',data=data)
# Out:
# <AxesSubplot:xlabel='blood_glucose_level', ylabel='count'>

# %%
sns.countplot(x='diabetes',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x='hypertension',data=data)
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='count'>

# %%
sns.countplot(x='age',data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.boxplot(x='gender',y='heart_disease',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='heart_disease'>

# %%
sns.boxplot(x='smoking_history',y='blood_glucose_level',data=data)
# Out:
# <AxesSubplot:xlabel='smoking_history', ylabel='blood_glucose_level'>

# %%
sns.boxplot(x='diabetes',y='bmi',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='bmi'>

# %%
sns.boxplot(x='diabetes',y='age',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='age'>

# %%
sns.boxplot(x='diabetes',y='HbA1c_level',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='HbA1c_level'>

# %%
sns.boxplot(x='diabetes',y='blood_glucose_level',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='blood_glucose_level'>

# %%
sns.scatterplot(x='age',y='bmi',hue='diabetes',data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(x='blood_glucose_level', y='bmi', hue='diabetes', data=data)
# Out:
# <AxesSubplot:xlabel='blood_glucose_level', ylabel='bmi'>

# %%
sns.scatterplot(x='blood_glucose_level', y='HbA1c_level', hue='diabetes', data=data)
# Out:
# <AxesSubplot:xlabel='blood_glucose_level', ylabel='HbA1c_level'>

# %%
sns.scatterplot(x='age', y='smoking_history', hue='diabetes', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='smoking_history'>

# %%
sns.violinplot(x='diabetes',y='bmi',hue='gender',split=False, data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='bmi'>

# %%
sns.violinplot(x='smoking_history',y='heart_disease',hue='diabetes',split=True, data=data)
# Out:
# <AxesSubplot:xlabel='smoking_history', ylabel='heart_disease'>

# %%
sns.boxplot(x='diabetes',y='bmi',hue='gender',data=data)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='bmi'>

# %%
sns.boxplot(x='blood_glucose_level',y='bmi',hue='gender',data=data)
# Out:
# <AxesSubplot:xlabel='blood_glucose_level', ylabel='bmi'>

# %%
data.describe().T
# Out:
#                         count        mean        std    min     25%     50%  \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
# diabetes             100000.0    0.085000   0.278883   0.00    0.00    0.00
#
#                         75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %%
sns.histplot(x="age", data=data, kde=True)
pt.title("Age Distribution")
pt.show()

# %%
sns.histplot(x="smoking_history", data=data, kde=True)
pt.title("smoking_history Distribution")
pt.show()

# %%
sns.histplot(x="heart_disease", data=data, kde=True)
pt.title("heart_disease Distribution")
pt.show()

# %%
sns.histplot(x="blood_glucose_level", data=data, kde=True)
pt.title("blood_glucose_level Distribution")
pt.show()

# %%
corr_m = data.corr()
sns.heatmap(corr_m, annot=True, cmap="coolwarm")
pt.title("Correlation Matrix")
pt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
sns.catplot(data=data,x="diabetes",
            y="blood_glucose_level",kind="boxen")

# %%
sns.catplot(data=data,x="diabetes",
            y="HbA1c_level",kind="boxen")

# %%
a=data.nunique()
print(a)
# Out:
# gender                    3
# age                     102
# hypertension              2
# heart_disease             2
# smoking_history           6
# bmi                    4247
# HbA1c_level              18
# blood_glucose_level      18
# diabetes                  2
# dtype: int64

# %%
data.gender.value_counts()
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
data["gender"].value_counts().plot(kind="bar", color =["pink", "black"],figsize=(10,6))
pt.title("According to Gender Distribution")
pt.ylabel("Count");
